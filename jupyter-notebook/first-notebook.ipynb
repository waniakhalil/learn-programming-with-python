# %% [markdown]
# # My First Notebook

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ## Learning NoteBook

# %% [markdown]
# ### I love Pakistan

# %%
print("1234")
# Out:
# 1234

# %% [markdown]
# #### I love myself
